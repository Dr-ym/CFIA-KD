# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
filename="/content/drive/My Drive/HAM10000.zip"
with ZipFile(filename,'r') as zip:
  zip.extractall()
  print("done")
# Out:
# done

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from keras import backend as K
from keras.layers import Layer,InputSpec
import keras.layers as kl
from glob import glob
from sklearn.metrics import roc_curve, auc
from keras.preprocessing import image
from tensorflow.keras.models import Sequential
from sklearn.metrics import roc_auc_score
from tensorflow.keras import callbacks
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from  matplotlib import pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras.layers import concatenate,Dense, Conv2D, MaxPooling2D, Flatten,Input,Activation,add,AveragePooling2D,BatchNormalization,Dropout
# %matplotlib inline
import shutil
from sklearn.metrics import  precision_score, recall_score, accuracy_score,classification_report ,confusion_matrix
from tensorflow.python.platform import build_info as tf_build_info
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
train_df = pd.read_csv('/code/MyCode/AUG/HAM10000/train.csv')
test_df = pd.read_csv('/code/MyCode/AUG/HAM10000/test.csv')

# %%
targetnames = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# %%
train_path = '/code/MyCode/AUG/HAM10000/train_dir'
test_path = '/code/MyCode/AUG/HAM10000/test_dir'
batch_size=16

# %%
datagen=ImageDataGenerator(preprocessing_function=tf.keras.applications.inception_resnet_v2.preprocess_input)

# %%
image_size = 224
print("\nTrain Batches: ")
train_batches = datagen.flow_from_directory(directory=train_path,
                                            target_size=(image_size,image_size),
                                            batch_size=batch_size,
                                            shuffle=True)

print("\nTest Batches: ")
test_batches =datagen.flow_from_directory(test_path,
                                           target_size=(image_size,image_size),
                                           batch_size=batch_size,
                                           shuffle=False)
# Out:
# Train Batches:
# Found 55115 images belonging to 7 classes.
#
# Test Batches:
# Found 2003 images belonging to 7 classes.

# %%
#Soft Attention

from keras import backend as K
from keras.layers import Layer,InputSpec
import keras.layers as kl
import tensorflow as tf



class SoftAttention(Layer):
    def __init__(self,ch,m,concat_with_x=False,aggregate=False,**kwargs):
        self.channels=int(ch)
        self.multiheads = m
        self.aggregate_channels = aggregate
        self.concat_input_with_scaled = concat_with_x


        super(SoftAttention,self).__init__(**kwargs)

    def build(self,input_shape):

        self.i_shape = input_shape

        kernel_shape_conv3d = (self.channels, 3, 3) + (1, self.multiheads) # DHWC

        self.out_attention_maps_shape = input_shape[0:1]+(self.multiheads,)+input_shape[1:-1]

        if self.aggregate_channels==False:

            self.out_features_shape = input_shape[:-1]+(input_shape[-1]+(input_shape[-1]*self.multiheads),)
        else:
            if self.concat_input_with_scaled:
                self.out_features_shape = input_shape[:-1]+(input_shape[-1]*2,)
            else:
                self.out_features_shape = input_shape


        self.kernel_conv3d = self.add_weight(shape=kernel_shape_conv3d,
                                        initializer='he_uniform',
                                        name='kernel_conv3d')
        self.bias_conv3d = self.add_weight(shape=(self.multiheads,),
                                      initializer='zeros',
                                      name='bias_conv3d')

        super(SoftAttention, self).build(input_shape)

    def call(self, x):

        exp_x = K.expand_dims(x,axis=-1)

        c3d = K.conv3d(exp_x,
                     kernel=self.kernel_conv3d,
                     strides=(1,1,self.i_shape[-1]), padding='same', data_format='channels_last')
        conv3d = K.bias_add(c3d,
                        self.bias_conv3d)
        conv3d = kl.Activation('relu')(conv3d)

        conv3d = K.permute_dimensions(conv3d,pattern=(0,4,1,2,3))


        conv3d = K.squeeze(conv3d, axis=-1)
        conv3d = K.reshape(conv3d,shape=(-1, self.multiheads ,self.i_shape[1]*self.i_shape[2]))

        softmax_alpha = K.softmax(conv3d, axis=-1)
        softmax_alpha = kl.Reshape(target_shape=(self.multiheads, self.i_shape[1],self.i_shape[2]))(softmax_alpha)


        if self.aggregate_channels==False:
            exp_softmax_alpha = K.expand_dims(softmax_alpha, axis=-1)
            exp_softmax_alpha = K.permute_dimensions(exp_softmax_alpha,pattern=(0,2,3,1,4))

            x_exp = K.expand_dims(x,axis=-2)

            u = kl.Multiply()([exp_softmax_alpha, x_exp])

            u = kl.Reshape(target_shape=(self.i_shape[1],self.i_shape[2],u.shape[-1]*u.shape[-2]))(u)

        else:
            exp_softmax_alpha = K.permute_dimensions(softmax_alpha,pattern=(0,2,3,1))

            exp_softmax_alpha = K.sum(exp_softmax_alpha,axis=-1)

            exp_softmax_alpha = K.expand_dims(exp_softmax_alpha, axis=-1)

            u = kl.Multiply()([exp_softmax_alpha, x])

        if self.concat_input_with_scaled:
            o = kl.Concatenate(axis=-1)([u,x])
        else:
            o = u

        return [o, softmax_alpha]

    def compute_output_shape(self, input_shape):
        return [self.out_features_shape, self.out_attention_maps_shape]


    def get_config(self):
        return super(SoftAttention,self).get_config()

# %%
densenet = tf.keras.applications.DenseNet201(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,

)
# Exclude the last 28 layers of the model.
conv = densenet.layers[-28].output

# %% [markdown]
# Soft Attention

# %%
attention_layer,map2 = SoftAttention(aggregate=True,m=16,concat_with_x=False,ch=int(conv.shape[-1]),name='soft_attention')(conv)
attention_layer=(MaxPooling2D(pool_size=(2, 2),padding="same")(attention_layer))
conv=(MaxPooling2D(pool_size=(2, 2),padding="same")(conv))

conv = concatenate([conv,attention_layer])
conv  = Activation('relu')(conv)
conv = Dropout(0.5)(conv)

# %%
output = Flatten()(conv)
output = Dense(7, activation='softmax')(output)
model = Model(inputs=densenet.input, outputs=output)

# %%
#model.summary()

# %%
opt1=tf.keras.optimizers.Adam(learning_rate=0.01,epsilon=0.1)
model.compile(optimizer=opt1,
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
checkpoint=  ModelCheckpoint(filepath = '/content/drive/My Drive/Densenet201+SA.hdf5',monitor='val_accuracy',save_best_only=True,save_weights_only=True)

# %%
Earlystop = EarlyStopping(monitor='val_loss', mode='min',patience=40, min_delta=0.001)
history = model.fit(train_batches,
                    steps_per_epoch=(len(train_df)/10),
                    epochs=50,
                    verbose=2,
                    validation_data=test_batches,validation_steps=len(test_df)/batch_size,callbacks=[checkpoint,Earlystop])
# Out:
# Epoch 1/50
# 801/801 - 430s - loss: 1.1577 - accuracy: 0.5687 - val_loss: 0.7858 - val_accuracy: 0.7434 - 430s/epoch - 537ms/step
# Epoch 2/50
# 801/801 - 307s - loss: 0.7453 - accuracy: 0.7315 - val_loss: 0.7184 - val_accuracy: 0.7449 - 307s/epoch - 383ms/step
# Epoch 3/50
# 801/801 - 306s - loss: 0.6166 - accuracy: 0.7720 - val_loss: 1.0030 - val_accuracy: 0.6875 - 306s/epoch - 382ms/step
# Epoch 4/50
# 801/801 - 308s - loss: 0.5528 - accuracy: 0.7943 - val_loss: 0.5923 - val_accuracy: 0.7833 - 308s/epoch - 384ms/step
# Epoch 5/50
# 801/801 - 309s - loss: 0.5116 - accuracy: 0.8137 - val_loss: 0.6869 - val_accuracy: 0.7713 - 309s/epoch - 386ms/step
# Epoch 6/50
# 801/801 - 309s - loss: 0.4453 - accuracy: 0.8404 - val_loss: 0.5848 - val_accuracy: 0.7833 - 309s/epoch - 385ms/step
# Epoch 7/50
# 801/801 - 311s - loss: 0.3987 - accuracy: 0.8550 - val_loss: 0.5410 - val_accuracy: 0.8043 - 311s/epoch - 388ms/step
# Epoch 8/50
# 801/801 - 306s - loss: 0.3636 - accuracy: 0.8651 - val_loss: 0.5850 - val_accuracy: 0.7873 - 306s/epoch - 382ms/step
# Epoch 9/50
# 801/801 - 306s - loss: 0.3464 - accuracy: 0.8745 - val_loss: 0.5337 - val_accuracy: 0.8128 - 306s/epoch - 382ms/step
# Epoch 10/50
# 801/801 - 308s - loss: 0.3215 - accuracy: 0.8844 - val_loss: 0.7002 - val_accuracy: 0.7584 - 308s/epoch - 384ms/step
# Epoch 11/50
# 801/801 - 305s - loss: 0.2951 - accuracy: 0.8900 - val_loss: 0.6017 - val_accuracy: 0.7863 - 305s/epoch - 381ms/step
# Epoch 12/50
# 801/801 - 307s - loss: 0.2760 - accuracy: 0.9020 - val_loss: 0.5016 - val_accuracy: 0.8228 - 307s/epoch - 383ms/step
# Epoch 13/50
# 801/801 - 306s - loss: 0.2513 - accuracy: 0.9100 - val_loss: 0.5390 - val_accuracy: 0.8168 - 306s/epoch - 381ms/step
# Epoch 14/50
# 801/801 - 304s - loss: 0.2394 - accuracy: 0.9146 - val_loss: 0.6554 - val_accuracy: 0.8093 - 304s/epoch - 380ms/step
# Epoch 15/50
# 801/801 - 304s - loss: 0.2281 - accuracy: 0.9144 - val_loss: 0.6644 - val_accuracy: 0.8053 - 304s/epoch - 379ms/step
# Epoch 16/50
# 801/801 - 304s - loss: 0.2104 - accuracy: 0.9255 - val_loss: 0.5935 - val_accuracy: 0.7963 - 304s/epoch - 380ms/step
# Epoch 17/50
# 801/801 - 306s - loss: 0.1923 - accuracy: 0.9294 - val_loss: 0.5839 - val_accuracy: 0.8203 - 306s/epoch - 382ms/step
# Epoch 18/50
# 801/801 - 305s - loss: 0.1980 - accuracy: 0.9320 - val_loss: 0.5389 - val_accuracy: 0.8337 - 305s/epoch - 381ms/step
# Epoch 19/50
# 801/801 - 305s - loss: 0.1887 - accuracy: 0.9334 - val_loss: 0.4708 - val_accuracy: 0.8422 - 305s/epoch - 380ms/step
# Epoch 20/50
# 801/801 - 304s - loss: 0.1676 - accuracy: 0.9418 - val_loss: 0.6187 - val_accuracy: 0.8198 - 304s/epoch - 380ms/step
# Epoch 21/50
# 801/801 - 304s - loss: 0.1651 - accuracy: 0.9400 - val_loss: 0.5371 - val_accuracy: 0.8248 - 304s/epoch - 379ms/step
# Epoch 22/50
# 801/801 - 303s - loss: 0.1500 - accuracy: 0.9446 - val_loss: 0.5520 - val_accuracy: 0.8213 - 303s/epoch - 379ms/step
# Epoch 23/50
# 801/801 - 307s - loss: 0.1534 - accuracy: 0.9440 - val_loss: 0.5620 - val_accuracy: 0.8303 - 307s/epoch - 383ms/step
# Epoch 24/50
# 801/801 - 304s - loss: 0.1431 - accuracy: 0.9490 - val_loss: 0.5890 - val_accuracy: 0.8268 - 304s/epoch - 379ms/step
# Epoch 25/50
# 801/801 - 305s - loss: 0.1354 - accuracy: 0.9511 - val_loss: 0.5110 - val_accuracy: 0.8318 - 305s/epoch - 381ms/step
# Epoch 26/50
# 801/801 - 309s - loss: 0.1334 - accuracy: 0.9540 - val_loss: 0.4943 - val_accuracy: 0.8487 - 309s/epoch - 386ms/step
# Epoch 27/50
# 801/801 - 307s - loss: 0.1187 - accuracy: 0.9578 - val_loss: 0.5187 - val_accuracy: 0.8492 - 307s/epoch - 383ms/step
# Epoch 28/50
# 801/801 - 304s - loss: 0.1274 - accuracy: 0.9525 - val_loss: 0.7963 - val_accuracy: 0.7798 - 304s/epoch - 380ms/step
# Epoch 29/50
# 801/801 - 307s - loss: 0.1143 - accuracy: 0.9603 - val_loss: 0.5032 - val_accuracy: 0.8477 - 307s/epoch - 384ms/step
# Epoch 30/50
# 801/801 - 303s - loss: 0.1016 - accuracy: 0.9663 - val_loss: 0.5669 - val_accuracy: 0.8337 - 303s/epoch - 378ms/step
# Epoch 31/50
# 801/801 - 307s - loss: 0.1113 - accuracy: 0.9615 - val_loss: 0.5941 - val_accuracy: 0.8258 - 307s/epoch - 383ms/step
# Epoch 32/50
# 801/801 - 303s - loss: 0.1126 - accuracy: 0.9593 - val_loss: 0.6208 - val_accuracy: 0.8268 - 303s/epoch - 378ms/step
# Epoch 33/50
# 801/801 - 303s - loss: 0.0919 - accuracy: 0.9661 - val_loss: 0.5556 - val_accuracy: 0.8342 - 303s/epoch - 378ms/step
# Epoch 34/50
# 801/801 - 303s - loss: 0.1035 - accuracy: 0.9627 - val_loss: 0.5574 - val_accuracy: 0.8318 - 303s/epoch - 378ms/step
# Epoch 35/50
# 801/801 - 304s - loss: 0.0913 - accuracy: 0.9695 - val_loss: 0.6371 - val_accuracy: 0.8347 - 304s/epoch - 379ms/step
# Epoch 36/50
# 801/801 - 304s - loss: 0.0868 - accuracy: 0.9696 - val_loss: 0.6478 - val_accuracy: 0.8342 - 304s/epoch - 379ms/step
# Epoch 37/50
# 801/801 - 305s - loss: 0.0793 - accuracy: 0.9723 - val_loss: 0.5378 - val_accuracy: 0.8607 - 305s/epoch - 381ms/step
# Epoch 38/50
# 801/801 - 303s - loss: 0.0881 - accuracy: 0.9694 - val_loss: 0.6935 - val_accuracy: 0.8283 - 303s/epoch - 378ms/step
# Epoch 39/50
# 801/801 - 304s - loss: 0.0820 - accuracy: 0.9708 - val_loss: 0.6104 - val_accuracy: 0.8298 - 304s/epoch - 380ms/step
# Epoch 40/50
# 801/801 - 304s - loss: 0.0672 - accuracy: 0.9750 - val_loss: 0.8326 - val_accuracy: 0.8083 - 304s/epoch - 380ms/step
# Epoch 41/50
# 801/801 - 305s - loss: 0.0705 - accuracy: 0.9752 - val_loss: 0.7082 - val_accuracy: 0.8522 - 305s/epoch - 380ms/step
# Epoch 42/50
# 801/801 - 305s - loss: 0.0750 - accuracy: 0.9740 - val_loss: 0.6119 - val_accuracy: 0.8492 - 305s/epoch - 380ms/step
# Epoch 43/50
# 801/801 - 305s - loss: 0.0780 - accuracy: 0.9743 - val_loss: 0.4997 - val_accuracy: 0.8567 - 305s/epoch - 380ms/step
# Epoch 44/50
# 801/801 - 303s - loss: 0.0599 - accuracy: 0.9796 - val_loss: 0.5446 - val_accuracy: 0.8532 - 303s/epoch - 379ms/step
# Epoch 45/50
# 801/801 - 305s - loss: 0.0688 - accuracy: 0.9772 - val_loss: 0.6161 - val_accuracy: 0.8452 - 305s/epoch - 380ms/step
# Epoch 46/50
# 801/801 - 305s - loss: 0.0629 - accuracy: 0.9787 - val_loss: 0.6649 - val_accuracy: 0.8417 - 305s/epoch - 380ms/step
# Epoch 47/50
# 801/801 - 304s - loss: 0.0663 - accuracy: 0.9765 - val_loss: 0.5373 - val_accuracy: 0.8607 - 304s/epoch - 379ms/step
# Epoch 48/50
# 801/801 - 304s - loss: 0.0583 - accuracy: 0.9786 - val_loss: 0.5389 - val_accuracy: 0.8692 - 304s/epoch - 379ms/step
# Epoch 49/50
# 801/801 - 307s - loss: 0.0535 - accuracy: 0.9801 - val_loss: 0.5823 - val_accuracy: 0.8597 - 307s/epoch - 383ms/step
# Epoch 50/50
# 801/801 - 305s - loss: 0.0587 - accuracy: 0.9797 - val_loss: 0.5936 - val_accuracy: 0.8587 - 305s/epoch - 380ms/step

# %%
# Retrieve a list of accuracy results on training and test data
# sets for each training epoch
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Retrieve a list of list results on training and test data
# sets for each training epoch
loss = history.history['loss']
val_loss = history.history['val_loss']

# Get number of epochs
epochs = range(len(acc))

# Plot training and validation accuracy per epoch
plt.plot(epochs, acc, label = "training")
plt.plot(epochs, val_acc, label = "validation")
plt.legend(loc="upper left")
plt.title('Training and validation accuracy')

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss, label = "training")
plt.plot(epochs, val_loss, label = "validation")
plt.legend(loc="upper right")
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
from tensorflow.keras import models
model.load_weights("Densenet201+SA.hdf5")

# %%
predictions = model.predict(test_batches, steps=len(test_df)/batch_size, verbose=0)

# %%
#geting predictions on test dataset
y_pred = np.argmax(predictions, axis=1)
targetnames = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
#getting the true labels per image
y_true = test_batches.classes
#getting the predicted labels per image
y_prob=predictions
from tensorflow.keras.utils import to_categorical
y_test = to_categorical(y_true)

# Creating classification report
report = classification_report(y_true, y_pred, target_names=targetnames)

print("\nClassification Report DenseNet201+SA:")
print(report)
# Out:
# Classification Report DenseNet201+SA:
#               precision    recall  f1-score   support
#
#        akiec       0.64      0.75      0.70        65
#          bcc       0.81      0.84      0.83       103
#          bkl       0.78      0.68      0.73       220
#           df       0.75      0.65      0.70        23
#          mel       0.76      0.62      0.68       223
#           nv       0.91      0.95      0.93      1341
#         vasc       0.96      0.96      0.96        28
#
#     accuracy                           0.87      2003
#    macro avg       0.80      0.78      0.79      2003
# weighted avg       0.87      0.87      0.87      2003

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix DenseNet201+SA',
                          cmap=plt.cm.Blues):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

confusion_mtx = confusion_matrix(y_true, y_pred)

# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = targetnames) 
plt.xlabel('True Label')
plt.ylabel('Pred Label')
# Out:
# Text(55.172222222222274, 0.5, 'Pred Label')

# %%
print("Average = 'weighted'")
print("Precision: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
print("Roc score: " + str(roc_auc_score(y_test,y_prob,multi_class='ovr',average='weighted')))

print("Average = 'macro'")
print("Precision: "+ str(precision_score(y_true, y_pred, average='macro')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='macro')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
print("Roc score: " + str(roc_auc_score(y_test,y_prob,multi_class='ovr',average='macro')))

print("Average = 'micro'")
print("Precision: "+ str(precision_score(y_true, y_pred, average='micro')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='micro')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
print("Roc score: " + str(roc_auc_score(y_test,y_prob,multi_class='ovr',average='micro')))
# Out:
# Average = 'weighted'
# Precision: 0.8656732264620671
# Recall: 0.8691962056914628
# Accuracy: 0.8691962056914628
# Roc score: 0.9628934402778737
# Average = 'macro'
# Precision: 0.803878981238239
# Recall: 0.7809144622355196
# Accuracy: 0.8691962056914628
# Roc score: 0.97554676898976
# Average = 'micro'
# Precision: 0.8691962056914628
# Recall: 0.8691962056914628
# Accuracy: 0.8691962056914628
# Roc score: 0.9871750038447072

# %%
fpr = {}
tpr = {}
roc_auc = {}
for i in range(7):
    r = roc_auc_score(y_test[:, i], y_prob[:, i])
    print("The ROC AUC score of "+targetnames[i]+" is: "+str(r))
# Out:
# The ROC AUC score of akiec is: 0.9821386044296261
# The ROC AUC score of bcc is: 0.9902784874808381
# The ROC AUC score of bkl is: 0.9640875949625248
# The ROC AUC score of df is: 0.99088713219148
# The ROC AUC score of mel is: 0.9395979241195143
# The ROC AUC score of nv is: 0.9622897193103401
# The ROC AUC score of vasc is: 0.9995479204339964

# %%
# Compute ROC curve and ROC area for each class
fpr = {}
tpr = {}
roc_auc = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_prob[:, i], drop_intermediate=False)
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
plt.plot(fpr[0], tpr[0],'v-',label='akiec: ROC curve of (area = %0.2f)' % roc_auc[0])
plt.plot(fpr[1], tpr[1],'c',label='bcc: ROC curve of (area = %0.2f)' % roc_auc[1])
plt.plot(fpr[2], tpr[2],'b',label='bkl: ROC curve of (area = %0.2f)' % roc_auc[2])
plt.plot(fpr[3], tpr[3],'g',label='df: ROC curve of (area = %0.2f)' % roc_auc[3])
plt.plot(fpr[4], tpr[4],'y',label='mel: ROC curve of (area = %0.2f)' % roc_auc[4])
plt.plot(fpr[5], tpr[5],'o-',label='nv: ROC curve of (area = %0.2f)' % roc_auc[5])
plt.plot(fpr[6], tpr[6],'r',label='vasc: ROC curve of (area = %0.2f)' % roc_auc[6])

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of DenseNet201+SA')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ATTENTION MAP

# %%
sa_model = Model(model.inputs,model.get_layer('soft_attention').output)
target_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']


for i in range(len(test_batches)):
    x_test,y_test=test_batches[i]
    sa_features, sa_maps = sa_model.predict(x_test)
    for j in range(len(x_test)):
        img_idx = j
        t = (x_test + 1)/2 
        fig, axes = plt.subplots(2, 1)
        axes[0].imshow(t[img_idx])
        class_predictions = model.predict(x_test)

        prediction_index = np.argmax(class_predictions[j])
        ground_truth_index = np.argmax(y_test[j])
        pred = target_names[prediction_index]
        gt = target_names[ground_truth_index]
        
        sum_attnmap = np.sum(sa_maps[img_idx],0)
        axes[1].imshow(t[img_idx],alpha=1.0)
        axes[1].imshow(cv2.resize(sum_attnmap,(224,224),interpolation=cv2.INTER_CUBIC),cmap='jet',alpha=0.5)
        axes[1].set_xlabel(f"Pred: {pred}, Gt: {gt}")
        
        if (pred == gt):
            plt.savefig('densenet/trueCases/plt_' + str(i) + '_' + str(j) + '.jpg')
        else: 
            plt.savefig('densenet/failCases/plt_' + str(i) + '_' + str(j) + '.jpg')
